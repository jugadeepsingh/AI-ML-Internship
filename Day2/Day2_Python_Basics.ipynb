# %% [markdown]
# # AI & ML Internship - Day 2
#
# ## Python Basics
#
# **Name:** Jugadeep Singh
#
# **Internship:** AI & Machine Learning
#
# **Company:** Codomax Digital Solutions
#
# **Task:** Python Basics

# %% [markdown]
# # Objectives
#
# - Learn Variables
# - Learn Data Types
# - Learn Operators
# - Learn Conditional Statements
# - Learn Loops
# - Learn Functions
# - Write Basic Python Programs

# %%
print("Welcome to Day 2")
print("Learning Python Basics")
# Out:
# Welcome to Day 2
# Learning Python Basics

# %% [markdown]
# # Variables

# %%
name = "Jugadeep Singh"
age = 19
course = "AI & ML"

print(name)
print(age)
print(course)
# Out:
# Jugadeep Singh
# 19
# AI & ML

# %% [markdown]
# # Data Types

# %%
integer = 25
decimal = 95.5
text = "Python"
status = True

print(type(integer))
print(type(decimal))
print(type(text))
print(type(status))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'str'>
# <class 'bool'>

# %% [markdown]
# # Operators

# %%
a = 20
b = 10

print("Addition:", a + b)
print("Subtraction:", a - b)
print("Multiplication:", a * b)
print("Division:", a / b)
print("Modulus:", a % b)
# Out:
# Addition: 30
# Subtraction: 10
# Multiplication: 200
# Division: 2.0
# Modulus: 0

# %% [markdown]
# # Conditional Statements

# %%
marks = 85

if marks >= 50:
    print("Pass")
else:
    print("Fail")
# Out:
# Pass

# %% [markdown]
# # Loops

# %%
print("For Loop")

for i in range(1, 6):
    print(i)

print("While Loop")

count = 1

while count <= 5:
    print(count)
    count += 1
# Out:
# For Loop
# 1
# 2
# 3
# 4
# 5
# While Loop
# 1
# 2
# 3
# 4
# 5

# %% [markdown]
# # Functions

# %%
def greet(name):
    print("Welcome", name)

greet("Jugadeep Singh")
# Out:
# Welcome Jugadeep Singh

# %% [markdown]
# # Simple Python Program

# %%
num1 = 15
num2 = 25

sum = num1 + num2

print("First Number:", num1)
print("Second Number:", num2)
print("Sum:", sum)
# Out:
# First Number: 15
# Second Number: 25
# Sum: 40

# %% [markdown]
# # Conclusion
#
# Today I learned the basics of Python including variables, data types, operators, conditional
# statements, loops, functions, and simple programs. These concepts form the foundation for
# upcoming Machine Learning tasks.
